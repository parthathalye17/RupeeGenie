# %%
import pytesseract

# %%
print(pytesseract.get_languages(config=''))
# Out:
# ['eng', 'osd', 'snum']

# %%
import pytesseract
from PIL import Image

# Path to your image file
image_path = './hindi_img.jpg'

# Open the image using PIL
img = Image.open(image_path)

# Use pytesseract to do OCR on the image using Hindi
text = pytesseract.image_to_string(img, lang='hin')

print(text)
# Out:
# श्र बैंक ऑफ़ बड़ौदा
# आधार प्रविष्टि एवं प्रमाणीकरण के लिए स्वीकृति फार्म “4-57
#
# शाखा प्रबंधक दिनांक:
#
# प्रिय महोदय/महोदया,
#
# मेरे/हमारेनाम पर बैंक खातासं, ररर
# खाते को आधार / यूआईडी संख्या के साथ लिंक करना और यूआईडीएआई के साथ प्रमाणीकरण.
# आपकी शाखा (आला का वास: ....८६६८--सपवलनतससससनकससनकननत नस 9 कसकघ9 5 ) में मेरा / हमारा बचत / चालू / बीकेसीसी खाता संख्या
#
# अल रहा है.
# . -----चल रहा है.
# /हम अपनी आधार संख्या/ओं को प्रस्तुत कर रहे हैं तथा स्वैच्छिक रूप से मैं / हम अपने उपर्युक्त खाता संख्या में मेरे / हमारे आधार
# संख्या/ओं की प्रविष्टि तथा यूआईडीएआई से प्रमाणीकरण हेतु सहमति प्रदान करते हैं: (टिक मार्क के माध्यम से उचित अनुरोध का चयन
#
# केवल गैर लेन-देन उद्देश्यों हेतु (किवायसी के रूप में)
#
# [_] मुझे/हमें भारत सरकार से मेरे/ हमारे उपर्युक्त खाते में प्रत्यक्ष लाभ अंतरण (डीबीटी) प्राप्त करने में सहायता हेतु एनपीसीआई में
# मैपिंग तथा मेरे आधार नंबर को यूआईडीएआई के साथ प्रमाणित करने के लिए. मैं / हम समझते हैं कि यदि मुझे / हमें एक से
# अधिक अंतरण लाभ मिलता है तो, मुझे / हमें मिलने वाले सभी अंतरण लाभ इसी खाते में प्राप्त होंगे.
#
# मेरे / हमारे खाता - -- (बैंक का नाम) से बैंक ऑफ़ बड़ौदा के साथ
# खोले गए उपर्युक्त खाते (डीबीटी लाभ की राशि की प्राप्ति हेतु) की एनपीसीआई मैपिंग में परिवर्तन के लिए
#
# [_] एईपीएस (आधार समर्थित भुगतान प्रणाली) और आधार प्रमाणीकरण समर्थित अन्य सेवाओं का लाभ लेने के लिए.
#
# आधार / यूआईडी विवरण निम्नानुसार हैः
#
# आधार / यूआईडी संख्या.
# आधार धारक का नाम जैसा आधार कार्ड पर हो. .............-----«०-न्‍>न्‍_न्‍-ञ-ञ--ञ>लनतञतनल न +«
#
# उपर्युक्त दिए गए विवरण मेरी/ हमारी पूर्ण जानकारी और समझ के अनुसार सत्य है. मैं / हम यह समझता / समझती हूं कि मेरे / हमारे द्वारा बैंक को
# प्रस्दुत की गई सृक्तता का उपयोग उपर्युक्त उल्लिबित उद्देश्यों: अथवा विधि की आवश्यकताओं के अलावा अन्य कह्लीं उपयोग नहीं होगा. मैं/ हम यह भी
# समझता / समझती हूं कि यदि पूर्व बैंक में पीएमजेनीवाय आतिदेय बकाया शेष रहता है तो बीबीटी लाभ श्राप्त करने के लिए पिछले बैंक से एनपीसीजाई
# मैफपिय को नहीं बदला जाएगा.
#
# भवदीय,
#
# (खाता धारक/कों के हस्ताक्षर / अंगूठे का निशान)
#
# नाम: ......................-----०"०>०>त्>त >> >> >> >> >त>>>त>ञतत>त>>> >> ल्‍्ज3««
# मोबाइल नं.
# ई-मेल ...
# संलग्रक: आधार पत्र की स्व-प्रमाणित प्रति
#
# बैंक खाते में आधार नंबर की प्रविष्टि / लिंकिंग की पुष्टि
# |]! 5.07. / अर मन मच के खातों सेंद्या ++नन्‍न्‍नललभभ्>->प>«भसभभ>>न>न>भ>न>>न>+«न+न9_भन>++«+_++« िंको
#
# पन > शोखों २+-न्‍-न्‍न्‍-लललनन>>>->-+++>++>+>+-+++++++- को आधार सं. _न्‍- अिन्‍ननननरन><भस<-><«<«_*
# से डीबीटी एवं एईपीएस दोनों / केवल एईपीएस / गैर लेन-देन उद्देश्य (केिवायसी के रूप में) के लिए लिंक कर दिया गया है.
#
# शाखा:
# दिनांक: (बैंक के प्राधिकृत अधिकारी)

# %%
import supabase
